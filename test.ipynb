# %%
import mysql.connector
import pandas as pd

# %%
with mysql.connector.connect(
    host="localhost",
    user="root",
    password="40363933",
    database='sparkifydb'
) as conn:
    cur = conn.cursor()
    cur.execute("SELECT * FROM songplays LIMIT 5;")
    rows = cur.fetchall()
    songplays = pd.DataFrame(rows, columns=[desc[0] for desc in cur.description])

# %%
songplays
# Out:
#    songplay_id          start_time  user_id level song_id artist_id  \
# 0            1 2018-11-01 21:01:47        8  free    None      None
# 1            2 2018-11-01 21:05:53        8  free    None      None
# 2            3 2018-11-01 21:08:17        8  free    None      None
# 3            4 2018-11-01 21:11:14        8  free    None      None
# 4            5 2018-11-01 21:17:34        8  free    None      None
#
#    session_id                     location  \
# 0         139  Phoenix-Mesa-Scottsdale, AZ
# 1         139  Phoenix-Mesa-Scottsdale, AZ
# 2         139  Phoenix-Mesa-Scottsdale, AZ
# 3         139  Phoenix-Mesa-Scottsdale, AZ
# 4         139  Phoenix-Mesa-Scottsdale, AZ
#
#                                           user_agent
# 0  "Mozilla/5.0 (Windows NT 6.1; WOW64) AppleWebK...
# 1  "Mozilla/5.0 (Windows NT 6.1; WOW64) AppleWebK...
# 2  "Mozilla/5.0 (Windows NT 6.1; WOW64) AppleWebK...
# 3  "Mozilla/5.0 (Windows NT 6.1; WOW64) AppleWebK...
# ...
